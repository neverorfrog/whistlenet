# %% [markdown]
# # Whistle Detection with Continuous Kernel Convolutional Networks

# %%
from config import *
import os
import warnings
warnings.filterwarnings("ignore")

config_path = os.path.join("config","config.yaml")
config: Config = load_config(config_path)
torch_config: TorchConfig = config.torch
dataset_config: DatasetConfig = config.dataset
trainer_config: TrainerConfig = config.trainer
baseline_config: BaselineConfig = config.baseline
whistlenet_config: WhistlenetConfig = config.whistlenet

from config.enums import Optimizer

print(list(Optimizer))
# Out:
# [<Optimizer.ASGD: 'ASGD'>, <Optimizer.Adadelta: 'Adadelta'>, <Optimizer.Adagrad: 'Adagrad'>, <Optimizer.Adam: 'Adam'>, <Optimizer.AdamW: 'AdamW'>, <Optimizer.Adamax: 'Adamax'>, <Optimizer.LBFGS: 'LBFGS'>, <Optimizer.NAdam: 'NAdam'>, <Optimizer.Optimizer: 'Optimizer'>, <Optimizer.RAdam: 'RAdam'>, <Optimizer.RMSprop: 'RMSprop'>, <Optimizer.Rprop: 'Rprop'>, <Optimizer.SGD: 'SGD'>, <Optimizer.SparseAdam: 'SparseAdam'>]

# %%
import torch
import numpy as np
torch.manual_seed(torch_config.seed)
np.random.seed(torch_config.seed)

# %% [markdown]
# Dataset Preparation

# %%
from whistlenet.data import WhistleDataset
from whistlenet.core.utils import plot, NUM_FREQS
from whistlenet.core.utils.audio import SampleType

dataset = WhistleDataset(dataset_config)
dataset.summarize()
reshaped = dataset.train_data.reshape((dataset.train_data.data.shape[0], NUM_FREQS))
plot(reshaped, dataset.train_data.labels, SampleType)
# Out:
# DATA SAVED!
# Train size: 228475
# Validation size: 9458
# Test size: 57906
# N Classes: 2
# Classes: [0. 1.]
#  - Class 0: 114244 (50.00284495021338)
#  - Class 1: 114231 (49.99715504978663)

# %%
from whistlenet.core.utils import Audio, project_root
projroot = project_root()
audio = Audio(name="KronosTest_RC22", datapath=f'{projroot}/data/whistle/raw/train_cut', labelpath=f'{projroot}/data/whistle/labels/train_cut')
audio.freq_plot()

# %% [markdown]
# Model Training

# %%
from whistlenet.models import WhistleNet, Baseline
from whistlenet.core.lightning import LightningTrainer

model = WhistleNet(in_channels=1, out_channels=1, config=whistlenet_config)
trainer = LightningTrainer(trainer_config)
trainer.fit(model,dataset)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#    | Name            | Type              | Params | Mode
# ---------------------------------------------------------------
# 0  | train_f1        | BinaryF1Score     | 0      | train
# 1  | train_precision | BinaryPrecision   | 0      | train
# 2  | train_recall    | BinaryRecall      | 0      | train
# 3  | train_accuracy  | BinaryAccuracy    | 0      | train
# 4  | val_f1          | BinaryF1Score     | 0      | train
# 5  | val_precision   | BinaryPrecision   | 0      | train
# 6  | val_recall      | BinaryRecall      | 0      | train
# 7  | val_accuracy    | BinaryAccuracy    | 0      | train
# 8  | test_f1         | BinaryF1Score     | 0      | train
# 9  | test_precision  | BinaryPrecision   | 0      | train
# 10 | test_recall     | BinaryRecall      | 0      | train
# 11 | test_accuracy   | BinaryAccuracy    | 0      | train
# 12 | backbone        | Sequential        | 8.7 K  | train
# 13 | pool            | AdaptiveMaxPool1d | 0      | train
# 14 | fc              | Sequential        | 545    | train
# ---------------------------------------------------------------
# 9.2 K     Trainable params
# 0         Non-trainable params
# 9.2 K     Total params
# 0.037     Total estimated model params size (MB)
# 85        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved. New best score: 0.710
# Epoch 0, global step 1785: 'val_loss' reached 0.71041 (best 0.71041), saving model to '/home/neverorfrog/code/whistle/whistlenet/ckpt/epoch=0-step=1785.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.266 >= min_delta = 1e-06. New best score: 0.445
# Epoch 1, global step 3570: 'val_loss' reached 0.44467 (best 0.44467), saving model to '/home/neverorfrog/code/whistle/whistlenet/ckpt/epoch=1-step=3570.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.096 >= min_delta = 1e-06. New best score: 0.349
# Epoch 2, global step 5355: 'val_loss' reached 0.34896 (best 0.34896), saving model to '/home/neverorfrog/code/whistle/whistlenet/ckpt/epoch=2-step=5355.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_loss improved by 0.066 >= min_delta = 1e-06. New best score: 0.283
# Epoch 3, global step 7140: 'val_loss' reached 0.28291 (best 0.28291), saving model to '/home/neverorfrog/code/whistle/whistlenet/ckpt/epoch=3-step=7140.ckpt' as top 1

# %% [markdown]
# Inference on test audio

# %%
import torch
import time
import lightning as L

audiolabels = audio.get_labels()
checkpoint_path = os.path.join(trainer_config.ckpt_path, "epoch=7-step=14376.ckpt")
model = WhistleNet.load_from_checkpoint(checkpoint_path, in_channels = 1, out_channels = 1, config=whistlenet_config)

def normalize(data: torch.Tensor, epsilon: float = 1e-6) -> torch.Tensor:
    min = data.min()
    max = data.max()
    data = (data - min) / (
        max - min + epsilon
    )  # Adding epsilon to avoid division by zero
    return data

def classify(window):
    with torch.inference_mode():
        start = time.time()
        confidence = model(window).item()
        print(f"Confidence: {confidence:.4f}")
        prediction = 1 if confidence > 0.5 else 0
        elapsed = time.time() - start
        print(f"Prediction: {prediction}, elapsed: {elapsed:.4f}")
        return prediction

# %%
for i in range(audio.frames):
    window = torch.from_numpy(audio.S[0,:,i].reshape(1,1,NUM_FREQS))
    window = normalize(window)
    print(f"frame {i}, time {audio.frame2time(i):.2f}")
    print(f"label: {audiolabels[0,i]}")
    classify(window)
    print()
# Out:
# frame 0, time 0.00
# label: 0.0
# Confidence: 0.3721
# Prediction: 0, elapsed: 0.0085
#
# frame 1, time 0.02
# label: 0.0
# Confidence: 0.4609
# Prediction: 0, elapsed: 0.0029
#
# frame 2, time 0.05
# label: 0.0
# Confidence: 0.3824
# Prediction: 0, elapsed: 0.0022
#
# frame 3, time 0.07
# label: 0.0
# Confidence: 0.5682
# Prediction: 1, elapsed: 0.0018
#
# frame 4, time 0.09
# label: 0.0
# Confidence: 0.5134
# Prediction: 1, elapsed: 0.0014
#
# frame 5, time 0.12
# label: 0.0
# Confidence: 0.4080
# Prediction: 0, elapsed: 0.0014
#
# frame 6, time 0.14
# label: 1.0
# Confidence: 0.5843
# Prediction: 1, elapsed: 0.0014
#
# frame 7, time 0.16
# label: 1.0
# Confidence: 0.5029
# Prediction: 1, elapsed: 0.0017
#
# frame 8, time 0.19
# label: 0.0
# Confidence: 0.4748
# Prediction: 0, elapsed: 0.0018
#
# frame 9, time 0.21
# label: 0.0
# Confidence: 0.5141
# Prediction: 1, elapsed: 0.0013
#
# frame 10, time 0.23
# label: 0.0
# Confidence: 0.4265
# Prediction: 0, elapsed: 0.0013
#
# frame 11, time 0.26
# label: 0.0
# Confidence: 0.4677
# Prediction: 0, elapsed: 0.0013
#
# frame 12, time 0.28
# label: 0.0
# Confidence: 0.4776
# Prediction: 0, elapsed: 0.0013
#
# frame 13, time 0.30
# label: 0.0
# Confidence: 0.4605
# Prediction: 0, elapsed: 0.0013
#
# frame 14, time 0.33
# label: 0.0
# Confidence: 0.3708
# Prediction: 0, elapsed: 0.0013
#
# frame 15, time 0.35
# label: 0.0
# Confidence: 0.4644
# Prediction: 0, elapsed: 0.0013
#
# frame 16, time 0.37
# label: 0.0
# Confidence: 0.3751
# Prediction: 0, elapsed: 0.0013
#
# frame 17, time 0.39
# label: 0.0
# Confidence: 0.4023
# Prediction: 0, elapsed: 0.0013
#
# frame 18, time 0.42
# label: 0.0
# Confidence: 0.5888
# Prediction: 1, elapsed: 0.0014
#
# frame 19, time 0.44
# label: 0.0
# Confidence: 0.3583
# Prediction: 0, elapsed: 0.0016
#
# frame 20, time 0.46
# label: 0.0
# Confidence: 0.5287
# Prediction: 1, elapsed: 0.0017
#
# frame 21, time 0.49
# label: 0.0
# Confidence: 0.4912
# Prediction: 0, elapsed: 0.0019
#
# frame 22, time 0.51
# label: 1.0
# Confidence: 0.4936
# Prediction: 0, elapsed: 0.0015
#
# frame 23, time 0.53
# label: 1.0
# Confidence: 0.4116
# Prediction: 0, elapsed: 0.0014
#
# frame 24, time 0.56
# label: 1.0
# Confidence: 0.4176
# Prediction: 0, elapsed: 0.0014
#
# frame 25, time 0.58
# label: 1.0
# Confidence: 0.3817
# Prediction: 0, elapsed: 0.0013
#
# frame 26, time 0.60
# label: 0.0
# Confidence: 0.6164
# Prediction: 1, elapsed: 0.0013
#
# frame 27, time 0.63
# label: 0.0
# Confidence: 0.5250
# Prediction: 1, elapsed: 0.0013
#
# frame 28, time 0.65
# label: 0.0
# Confidence: 0.4914
# Prediction: 0, elapsed: 0.0013
#
# frame 29, time 0.67
# label: 0.0
# Confidence: 0.5542
# Prediction: 1, elapsed: 0.0016
#
# frame 30, time 0.70
# label: 0.0
# Confidence: 0.4134
# Prediction: 0, elapsed: 0.0018
#
# frame 31, time 0.72
# label: 0.0
# Confidence: 0.4765
# Prediction: 0, elapsed: 0.0014
#
# frame 32, time 0.74
# label: 0.0
# Confidence: 0.4505
# Prediction: 0, elapsed: 0.0016
#
# frame 33, time 0.77
# label: 0.0
# Confidence: 0.4968
# Prediction: 0, elapsed: 0.0017
#
# frame 34, time 0.79
# label: 0.0
# Confidence: 0.4206
# Prediction: 0, elapsed: 0.0013
#
# frame 35, time 0.81
# label: 0.0
# Confidence: 0.5679
# Prediction: 1, elapsed: 0.0014
#
# frame 36, time 0.84
# label: 0.0
# Confidence: 0.4740
# Prediction: 0, elapsed: 0.0013
#
# frame 37, time 0.86
# label: 1.0
# Confidence: 0.3608
# Prediction: 0, elapsed: 0.0013
#
# frame 38, time 0.88
# label: 1.0
# Confidence: 0.4547
# Prediction: 0, elapsed: 0.0013
#
# frame 39, time 0.91
# label: 1.0
# Confidence: 0.5061
# Prediction: 1, elapsed: 0.0014
#
# frame 40, time 0.93
# label: 0.0
# Confidence: 0.5070
# Prediction: 1, elapsed: 0.0016
#
# frame 41, time 0.95
# label: 0.0
# Confidence: 0.4554
# Prediction: 0, elapsed: 0.0015
#
# frame 42, time 0.98
# label: 0.0
# Confidence: 0.5664
# Prediction: 1, elapsed: 0.0013
#
# frame 43, time 1.00
# label: 0.0
# Confidence: 0.4492
# Prediction: 0, elapsed: 0.0013
#
# frame 44, time 1.02
# label: 0.0
# Confidence: 0.4582
# Prediction: 0, elapsed: 0.0013
#
# frame 45, time 1.04
# label: 0.0
# Confidence: 0.5318
# Prediction: 1, elapsed: 0.0013
#
# frame 46, time 1.07
# label: 0.0
# Confidence: 0.4709
# Prediction: 0, elapsed: 0.0013
#
# frame 47, time 1.09
# label: 0.0
# Confidence: 0.3987
# Prediction: 0, elapsed: 0.0013
#
# frame 48, time 1.11
# label: 0.0
# Confidence: 0.3113
# Prediction: 0, elapsed: 0.0013
#
# frame 49, time 1.14
# label: 0.0
# Confidence: 0.3094
# Prediction: 0, elapsed: 0.0012
#
# frame 50, time 1.16
# label: 0.0
# Confidence: 0.5130
# Prediction: 1, elapsed: 0.0013
#
# frame 51, time 1.18
# label: 0.0
# Confidence: 0.3707
# Prediction: 0, elapsed: 0.0013
#
# frame 52, time 1.21
# label: 0.0
# Confidence: 0.3694
# Prediction: 0, elapsed: 0.0013
#
# frame 53, time 1.23
# label: 0.0
# Confidence: 0.3074
# Prediction: 0, elapsed: 0.0013
#
# frame 54, time 1.25
# label: 0.0
# Confidence: 0.3571
# Prediction: 0, elapsed: 0.0014
#
# frame 55, time 1.28
# label: 0.0
# Confidence: 0.2617
# Prediction: 0, elapsed: 0.0014
#
# frame 56, time 1.30
# label: 0.0
# Confidence: 0.3675
# Prediction: 0, elapsed: 0.0013
#
# frame 57, time 1.32
# label: 0.0
# Confidence: 0.5257
# Prediction: 1, elapsed: 0.0013
#
# frame 58, time 1.35
# label: 0.0
# Confidence: 0.5488
# Prediction: 1, elapsed: 0.0013
#
# frame 59, time 1.37
# label: 0.0
# Confidence: 0.5064
# Prediction: 1, elapsed: 0.0013
#
# frame 60, time 1.39
# label: 0.0
# Confidence: 0.4184
# Prediction: 0, elapsed: 0.0013
#
# frame 61, time 1.42
# label: 0.0
# Confidence: 0.4104
# Prediction: 0, elapsed: 0.0013
#
# frame 62, time 1.44
# label: 1.0
# Confidence: 0.5445
# Prediction: 1, elapsed: 0.0013
#
# frame 63, time 1.46
# label: 1.0
# Confidence: 0.3114
# Prediction: 0, elapsed: 0.0013
#
# frame 64, time 1.49
# label: 1.0
# Confidence: 0.4987
# Prediction: 0, elapsed: 0.0013
#
# frame 65, time 1.51
# label: 0.0
# Confidence: 0.5417
# Prediction: 1, elapsed: 0.0014
#
# frame 66, time 1.53
# label: 0.0
# Confidence: 0.5238
# Prediction: 1, elapsed: 0.0014
#
# frame 67, time 1.56
# label: 0.0
# Confidence: 0.3736
# Prediction: 0, elapsed: 0.0014
#
# frame 68, time 1.58
# label: 0.0
# Confidence: 0.6025
# Prediction: 1, elapsed: 0.0021
#
# frame 69, time 1.60
# label: 0.0
# Confidence: 0.5114
# Prediction: 1, elapsed: 0.0014
#
# frame 70, time 1.63
# label: 0.0
# Confidence: 0.6623
# Prediction: 1, elapsed: 0.0013
#
# frame 71, time 1.65
# label: 0.0
# Confidence: 0.4640
# Prediction: 0, elapsed: 0.0013
#
# frame 72, time 1.67
# label: 0.0
# Confidence: 0.5361
# Prediction: 1, elapsed: 0.0013
#
# frame 73, time 1.70
# label: 0.0
# Confidence: 0.5796
# Prediction: 1, elapsed: 0.0014
#
# frame 74, time 1.72
# label: 0.0
# Confidence: 0.5641
# Prediction: 1, elapsed: 0.0014
#
# frame 75, time 1.74
# label: 0.0
# Confidence: 0.6145
# Prediction: 1, elapsed: 0.0018
#
# frame 76, time 1.76
# label: 0.0
# Confidence: 0.4468
# Prediction: 0, elapsed: 0.0016
#
# frame 77, time 1.79
# label: 0.0
# Confidence: 0.5294
# Prediction: 1, elapsed: 0.0013
#
# frame 78, time 1.81
# label: 0.0
# Confidence: 0.5739
# Prediction: 1, elapsed: 0.0014
#
# frame 79, time 1.83
# label: 0.0
# Confidence: 0.3573
# Prediction: 0, elapsed: 0.0013
#
# frame 80, time 1.86
# label: 0.0
# Confidence: 0.5496
# Prediction: 1, elapsed: 0.0013
#
# frame 81, time 1.88
# label: 0.0
# Confidence: 0.4992
# Prediction: 0, elapsed: 0.0013
#
# frame 82, time 1.90
# label: 0.0
# Confidence: 0.5389
# Prediction: 1, elapsed: 0.0013
#
# frame 83, time 1.93
# label: 0.0
# Confidence: 0.5579
# Prediction: 1, elapsed: 0.0013
#
# frame 84, time 1.95
# label: 0.0
# Confidence: 0.4937
# Prediction: 0, elapsed: 0.0013
#
# frame 85, time 1.97
# label: 0.0
# Confidence: 0.4163
# Prediction: 0, elapsed: 0.0014
#
# frame 86, time 2.00
# label: 0.0
# Confidence: 0.3248
# Prediction: 0, elapsed: 0.0016
#
# frame 87, time 2.02
# label: 1.0
# Confidence: 0.5122
# Prediction: 1, elapsed: 0.0016
#
# frame 88, time 2.04
# label: 1.0
# Confidence: 0.3752
# Prediction: 0, elapsed: 0.0013
#
# frame 89, time 2.07
# label: 1.0
# Confidence: 0.3354
# Prediction: 0, elapsed: 0.0013
#
# frame 90, time 2.09
# label: 0.0
# Confidence: 0.4458
# Prediction: 0, elapsed: 0.0013
#
# frame 91, time 2.11
# label: 0.0
# Confidence: 0.3471
# Prediction: 0, elapsed: 0.0013
#
# frame 92, time 2.14
# label: 0.0
# Confidence: 0.5458
# Prediction: 1, elapsed: 0.0013
#
# frame 93, time 2.16
# label: 0.0
# Confidence: 0.3511
# Prediction: 0, elapsed: 0.0013
#
# frame 94, time 2.18
# label: 0.0
# Confidence: 0.5062
# Prediction: 1, elapsed: 0.0013
#
# frame 95, time 2.21
# label: 0.0
# Confidence: 0.5691
# Prediction: 1, elapsed: 0.0012
#
# frame 96, time 2.23
# label: 0.0
# Confidence: 0.7300
# Prediction: 1, elapsed: 0.0013
#
# frame 97, time 2.25
# label: 0.0
# Confidence: 0.3152
# Prediction: 0, elapsed: 0.0013
#
# frame 98, time 2.28
# label: 0.0
# Confidence: 0.4709
# Prediction: 0, elapsed: 0.0015
#
# frame 99, time 2.30
# label: 0.0
# Confidence: 0.3961
# Prediction: 0, elapsed: 0.0013
#
# frame 100, time 2.32
# label: 0.0
# Confidence: 0.4746
# Prediction: 0, elapsed: 0.0013
#
# frame 101, time 2.35
# label: 0.0
# Confidence: 0.3770
# Prediction: 0, elapsed: 0.0013
#
# frame 102, time 2.37
# label: 0.0
# Confidence: 0.5154
# Prediction: 1, elapsed: 0.0013
#
# frame 103, time 2.39
# label: 1.0
# Confidence: 0.4394
# Prediction: 0, elapsed: 0.0013
#
# frame 104, time 2.41
# label: 1.0
# Confidence: 0.5113
# Prediction: 1, elapsed: 0.0013
#
# frame 105, time 2.44
# label: 1.0
# Confidence: 0.4211
# Prediction: 0, elapsed: 0.0013
#
# frame 106, time 2.46
# label: 0.0
# Confidence: 0.4502
# Prediction: 0, elapsed: 0.0013
#
# frame 107, time 2.48
# label: 0.0
# Confidence: 0.5717
# Prediction: 1, elapsed: 0.0013
#
# frame 108, time 2.51
# label: 0.0
# Confidence: 0.4710
# Prediction: 0, elapsed: 0.0013
#
# frame 109, time 2.53
# label: 0.0
# Confidence: 0.6203
# Prediction: 1, elapsed: 0.0015
#
# frame 110, time 2.55
# label: 0.0
# Confidence: 0.4133
# Prediction: 0, elapsed: 0.0016
#
# frame 111, time 2.58
# label: 0.0
# Confidence: 0.4992
# Prediction: 0, elapsed: 0.0013
#
# frame 112, time 2.60
# label: 0.0
# Confidence: 0.4763
# Prediction: 0, elapsed: 0.0014
#
# frame 113, time 2.62
# label: 0.0
# Confidence: 0.2399
# Prediction: 0, elapsed: 0.0013
#
# frame 114, time 2.65
# label: 0.0
# Confidence: 0.5060
# Prediction: 1, elapsed: 0.0013
#
# frame 115, time 2.67
# label: 0.0
# Confidence: 0.4191
# Prediction: 0, elapsed: 0.0013
#
# frame 116, time 2.69
# label: 0.0
# Confidence: 0.4610
# Prediction: 0, elapsed: 0.0013
#
# frame 117, time 2.72
# label: 0.0
# Confidence: 0.5188
# Prediction: 1, elapsed: 0.0013
#
# frame 118, time 2.74
# label: 0.0
# Confidence: 0.4854
# Prediction: 0, elapsed: 0.0013
#
# frame 119, time 2.76
# label: 0.0
# Confidence: 0.3646
# Prediction: 0, elapsed: 0.0013
#
# frame 120, time 2.79
# label: 0.0
# Confidence: 0.5125
# Prediction: 1, elapsed: 0.0013
#
# frame 121, time 2.81
# label: 1.0
# Confidence: 0.5235
# Prediction: 1, elapsed: 0.0013
#
# frame 122, time 2.83
# label: 1.0
# Confidence: 0.2809
# Prediction: 0, elapsed: 0.0014
#
# frame 123, time 2.86
# label: 1.0
# Confidence: 0.4288
# Prediction: 0, elapsed: 0.0015
#
# frame 124, time 2.88
# label: 1.0
# Confidence: 0.3883
# Prediction: 0, elapsed: 0.0018
#
# frame 125, time 2.90
# label: 1.0
# Confidence: 0.4213
# Prediction: 0, elapsed: 0.0013
#
# frame 126, time 2.93
# label: 0.0
# Confidence: 0.3684
# Prediction: 0, elapsed: 0.0013
#
# frame 127, time 2.95
# label: 0.0
# Confidence: 0.4386
# Prediction: 0, elapsed: 0.0013
#
# frame 128, time 2.97
# label: 0.0
# Confidence: 0.3560
# Prediction: 0, elapsed: 0.0013
#
# frame 129, time 3.00
# label: 0.0
# Confidence: 0.4805
# Prediction: 0, elapsed: 0.0018
#
# frame 130, time 3.02
# label: 0.0
# Confidence: 0.5058
# Prediction: 1, elapsed: 0.0015
#
# frame 131, time 3.04
# label: 0.0
# Confidence: 0.5785
# Prediction: 1, elapsed: 0.0014
#
# frame 132, time 3.07
# label: 0.0
# Confidence: 0.3599
# Prediction: 0, elapsed: 0.0016
#
# frame 133, time 3.09
# label: 0.0
# Confidence: 0.4321
# Prediction: 0, elapsed: 0.0020
#
# frame 134, time 3.11
# label: 0.0
# Confidence: 0.5239
# Prediction: 1, elapsed: 0.0021
#
# frame 135, time 3.13
# label: 0.0
# Confidence: 0.5099
# Prediction: 1, elapsed: 0.0020
#
# frame 136, time 3.16
# label: 0.0
# Confidence: 0.5004
# Prediction: 1, elapsed: 0.0015
#
# frame 137, time 3.18
# label: 0.0
# Confidence: 0.4321
# Prediction: 0, elapsed: 0.0015
#
# frame 138, time 3.20
# label: 0.0
# Confidence: 0.4783
# Prediction: 0, elapsed: 0.0014
#
# frame 139, time 3.23
# label: 0.0
# Confidence: 0.3361
# Prediction: 0, elapsed: 0.0016
#
# frame 140, time 3.25
# label: 0.0
# Confidence: 0.4943
# Prediction: 0, elapsed: 0.0025
#
# frame 141, time 3.27
# label: 0.0
# Confidence: 0.3998
# Prediction: 0, elapsed: 0.0021
#
# frame 142, time 3.30
# label: 1.0
# Confidence: 0.3658
# Prediction: 0, elapsed: 0.0016
#
# frame 143, time 3.32
# label: 1.0
# Confidence: 0.4295
# Prediction: 0, elapsed: 0.0017
#
# frame 144, time 3.34
# label: 1.0
# Confidence: 0.5129
# Prediction: 1, elapsed: 0.0020
#
# frame 145, time 3.37
# label: 1.0
# Confidence: 0.5077
# Prediction: 1, elapsed: 0.0020
#
# frame 146, time 3.39
# label: 0.0
# Confidence: 0.6265
# Prediction: 1, elapsed: 0.0019
#
# frame 147, time 3.41
# label: 0.0
# Confidence: 0.5162
# Prediction: 1, elapsed: 0.0017
#
# frame 148, time 3.44
# label: 0.0
# Confidence: 0.5201
# Prediction: 1, elapsed: 0.0020
#
# frame 149, time 3.46
# label: 0.0
# Confidence: 0.5383
# Prediction: 1, elapsed: 0.0024
#
# frame 150, time 3.48
# label: 0.0
# Confidence: 0.3809
# Prediction: 0, elapsed: 0.0016
#
# frame 151, time 3.51
# label: 0.0
# Confidence: 0.5103
# Prediction: 1, elapsed: 0.0015
#
# frame 152, time 3.53
# label: 0.0
# Confidence: 0.4578
# Prediction: 0, elapsed: 0.0015
#
# frame 153, time 3.55
# label: 0.0
# Confidence: 0.5210
# Prediction: 1, elapsed: 0.0015
#
# frame 154, time 3.58
# label: 0.0
# Confidence: 0.4935
# Prediction: 0, elapsed: 0.0016
#
# frame 155, time 3.60
# label: 0.0
# Confidence: 0.4886
# Prediction: 0, elapsed: 0.0016
#
# frame 156, time 3.62
# label: 0.0
# Confidence: 0.4698
# Prediction: 0, elapsed: 0.0016
#
# frame 157, time 3.65
# label: 0.0
# Confidence: 0.4417
# Prediction: 0, elapsed: 0.0015
#
# frame 158, time 3.67
# label: 0.0
# Confidence: 0.5458
# Prediction: 1, elapsed: 0.0016
#
# frame 159, time 3.69
# label: 0.0
# Confidence: 0.4251
# Prediction: 0, elapsed: 0.0022
#
# frame 160, time 3.72
# label: 1.0
# Confidence: 0.3457
# Prediction: 0, elapsed: 0.0017
#
# frame 161, time 3.74
# label: 1.0
# Confidence: 0.3332
# Prediction: 0, elapsed: 0.0015
#
# frame 162, time 3.76
# label: 1.0
# Confidence: 0.4229
# Prediction: 0, elapsed: 0.0014
#
# frame 163, time 3.78
# label: 1.0
# Confidence: 0.5788
# Prediction: 1, elapsed: 0.0013
#
# frame 164, time 3.81
# label: 0.0
# Confidence: 0.4014
# Prediction: 0, elapsed: 0.0014
#
# frame 165, time 3.83
# label: 0.0
# Confidence: 0.3810
# Prediction: 0, elapsed: 0.0013
#
# frame 166, time 3.85
# label: 0.0
# Confidence: 0.4440
# Prediction: 0, elapsed: 0.0014
#
# frame 167, time 3.88
# label: 0.0
# Confidence: 0.4246
# Prediction: 0, elapsed: 0.0013
#
# frame 168, time 3.90
# label: 0.0
# Confidence: 0.4345
# Prediction: 0, elapsed: 0.0016
#
# frame 169, time 3.92
# label: 0.0
# Confidence: 0.5216
# Prediction: 1, elapsed: 0.0021
#
# frame 170, time 3.95
# label: 0.0
# Confidence: 0.3306
# Prediction: 0, elapsed: 0.0018
#
# frame 171, time 3.97
# label: 0.0
# Confidence: 0.4137
# Prediction: 0, elapsed: 0.0014
#
# frame 172, time 3.99
# label: 0.0
# Confidence: 0.4457
# Prediction: 0, elapsed: 0.0015
#
# frame 173, time 4.02
# label: 0.0
# Confidence: 0.4871
# Prediction: 0, elapsed: 0.0015
#
# frame 174, time 4.04
# label: 0.0
# Confidence: 0.5566
# Prediction: 1, elapsed: 0.0014
#
# frame 175, time 4.06
# label: 0.0
# Confidence: 0.5298
# Prediction: 1, elapsed: 0.0013
#
# frame 176, time 4.09
# label: 0.0
# Confidence: 0.5468
# Prediction: 1, elapsed: 0.0013
#
# frame 177, time 4.11
# label: 0.0
# Confidence: 0.5871
# Prediction: 1, elapsed: 0.0014
#
# frame 178, time 4.13
# label: 0.0
# Confidence: 0.4673
# Prediction: 0, elapsed: 0.0018
#
# frame 179, time 4.16
# label: 0.0
# Confidence: 0.5285
# Prediction: 1, elapsed: 0.0025
#
# frame 180, time 4.18
# label: 0.0
# Confidence: 0.5068
# Prediction: 1, elapsed: 0.0015
#
# frame 181, time 4.20
# label: 0.0
# Confidence: 0.3980
# Prediction: 0, elapsed: 0.0015
#
# frame 182, time 4.23
# label: 1.0
# Confidence: 0.4054
# Prediction: 0, elapsed: 0.0016
#
# frame 183, time 4.25
# label: 1.0
# Confidence: 0.3776
# Prediction: 0, elapsed: 0.0014
#
# frame 184, time 4.27
# label: 1.0
# Confidence: 0.5419
# Prediction: 1, elapsed: 0.0013
#
# frame 185, time 4.30
# label: 0.0
# Confidence: 0.4071
# Prediction: 0, elapsed: 0.0013
#
# frame 186, time 4.32
# label: 0.0
# Confidence: 0.5162
# Prediction: 1, elapsed: 0.0014
#
# frame 187, time 4.34
# label: 0.0
# Confidence: 0.4370
# Prediction: 0, elapsed: 0.0013
#
# frame 188, time 4.37
# label: 0.0
# Confidence: 0.5334
# Prediction: 1, elapsed: 0.0015
#
# frame 189, time 4.39
# label: 0.0
# Confidence: 0.5089
# Prediction: 1, elapsed: 0.0019
#
# frame 190, time 4.41
# label: 0.0
# Confidence: 0.6335
# Prediction: 1, elapsed: 0.0017
#
# frame 191, time 4.44
# label: 0.0
# Confidence: 0.5567
# Prediction: 1, elapsed: 0.0015
#
# frame 192, time 4.46
# label: 0.0
# Confidence: 0.4747
# Prediction: 0, elapsed: 0.0016
#
# frame 193, time 4.48
# label: 0.0
# Confidence: 0.5017
# Prediction: 1, elapsed: 0.0014
#
# frame 194, time 4.50
# label: 0.0
# Confidence: 0.5544
# Prediction: 1, elapsed: 0.0015
#
# frame 195, time 4.53
# label: 0.0
# Confidence: 0.5919
# Prediction: 1, elapsed: 0.0014
#
# frame 196, time 4.55
# label: 0.0
# Confidence: 0.5017
# Prediction: 1, elapsed: 0.0014
#
# frame 197, time 4.57
# label: 0.0
# Confidence: 0.4434
# Prediction: 0, elapsed: 0.0014
#
# frame 198, time 4.60
# label: 0.0
# Confidence: 0.3122
# Prediction: 0, elapsed: 0.0016
#
# frame 199, time 4.62
# label: 0.0
# Confidence: 0.5421
# Prediction: 1, elapsed: 0.0018
#
# frame 200, time 4.64
# label: 0.0
# Confidence: 0.4299
# Prediction: 0, elapsed: 0.0018
#
# frame 201, time 4.67
# label: 0.0
# Confidence: 0.3681
# Prediction: 0, elapsed: 0.0015
#
# frame 202, time 4.69
# label: 0.0
# Confidence: 0.3437
# Prediction: 0, elapsed: 0.0014
#
# frame 203, time 4.71
# label: 0.0
# Confidence: 0.4152
# Prediction: 0, elapsed: 0.0015
#
# frame 204, time 4.74
# label: 0.0
# Confidence: 0.4492
# Prediction: 0, elapsed: 0.0018
#
# frame 205, time 4.76
# label: 0.0
# Confidence: 0.4225
# Prediction: 0, elapsed: 0.0021
#
# frame 206, time 4.78
# label: 0.0
# Confidence: 0.5574
# Prediction: 1, elapsed: 0.0015
#
# frame 207, time 4.81
# label: 1.0
# Confidence: 0.2835
# Prediction: 0, elapsed: 0.0016
#
# frame 208, time 4.83
# label: 1.0
# Confidence: 0.2997
# Prediction: 0, elapsed: 0.0016
#
# frame 209, time 4.85
# label: 1.0
# Confidence: 0.4095
# Prediction: 0, elapsed: 0.0018
#
# frame 210, time 4.88
# label: 0.0
# Confidence: 0.3879
# Prediction: 0, elapsed: 0.0015
#
# frame 211, time 4.90
# label: 0.0
# Confidence: 0.5362
# Prediction: 1, elapsed: 0.0016
#
# frame 212, time 4.92
# label: 0.0
# Confidence: 0.6270
# Prediction: 1, elapsed: 0.0020
#
# frame 213, time 4.95
# label: 0.0
# Confidence: 0.5418
# Prediction: 1, elapsed: 0.0015
#
# frame 214, time 4.97
# label: 0.0
# Confidence: 0.5462
# Prediction: 1, elapsed: 0.0014
#
# frame 215, time 4.99
# label: 0.0
# Confidence: 0.4827
# Prediction: 0, elapsed: 0.0013
#
# frame 216, time 5.02
# label: 0.0
# Confidence: 0.4139
# Prediction: 0, elapsed: 0.0013
#
# frame 217, time 5.04
# label: 0.0
# Confidence: 0.3950
# Prediction: 0, elapsed: 0.0015
#
# frame 218, time 5.06
# label: 0.0
# Confidence: 0.3413
# Prediction: 0, elapsed: 0.0014
#
# frame 219, time 5.09
# label: 0.0
# Confidence: 0.4088
# Prediction: 0, elapsed: 0.0017
#
# frame 220, time 5.11
# label: 0.0
# Confidence: 0.5304
# Prediction: 1, elapsed: 0.0020
#
# frame 221, time 5.13
# label: 0.0
# Confidence: 0.4851
# Prediction: 0, elapsed: 0.0018
#
# frame 222, time 5.15
# label: 0.0
# Confidence: 0.4677
# Prediction: 0, elapsed: 0.0014
#
# frame 223, time 5.18
# label: 0.0
# Confidence: 0.5039
# Prediction: 1, elapsed: 0.0014
#
# frame 224, time 5.20
# label: 0.0
# Confidence: 0.4512
# Prediction: 0, elapsed: 0.0014
#
# frame 225, time 5.22
# label: 1.0
# Confidence: 0.6261
# Prediction: 1, elapsed: 0.0015
#
# frame 226, time 5.25
# label: 1.0
# Confidence: 0.3852
# Prediction: 0, elapsed: 0.0015
#
# frame 227, time 5.27
# label: 1.0
# Confidence: 0.5915
# Prediction: 1, elapsed: 0.0015
#
# frame 228, time 5.29
# label: 1.0
# Confidence: 0.6121
# Prediction: 1, elapsed: 0.0018
#
# frame 229, time 5.32
# label: 0.0
# Confidence: 0.6505
# Prediction: 1, elapsed: 0.0015
#
# frame 230, time 5.34
# label: 0.0
# Confidence: 0.4591
# Prediction: 0, elapsed: 0.0014
#
# frame 231, time 5.36
# label: 0.0
# Confidence: 0.4618
# Prediction: 0, elapsed: 0.0014
#
# frame 232, time 5.39
# label: 0.0
# Confidence: 0.5987
# Prediction: 1, elapsed: 0.0014
#
# frame 233, time 5.41
# label: 0.0
# Confidence: 0.5622
# Prediction: 1, elapsed: 0.0013
#
# frame 234, time 5.43
# label: 0.0
# Confidence: 0.4571
# Prediction: 0, elapsed: 0.0013
#
# frame 235, time 5.46
# label: 0.0
# Confidence: 0.4046
# Prediction: 0, elapsed: 0.0013
#
# frame 236, time 5.48
# label: 0.0
# Confidence: 0.3768
# Prediction: 0, elapsed: 0.0014
#
# frame 237, time 5.50
# label: 0.0
# Confidence: 0.5607
# Prediction: 1, elapsed: 0.0013
#
# frame 238, time 5.53
# label: 0.0
# Confidence: 0.4534
# Prediction: 0, elapsed: 0.0013
#
# frame 239, time 5.55
# label: 0.0
# Confidence: 0.5896
# Prediction: 1, elapsed: 0.0013
#
# frame 240, time 5.57
# label: 0.0
# Confidence: 0.4642
# Prediction: 0, elapsed: 0.0014
#
# frame 241, time 5.60
# label: 0.0
# Confidence: 0.4976
# Prediction: 0, elapsed: 0.0014
#
# frame 242, time 5.62
# label: 0.0
# Confidence: 0.4792
# Prediction: 0, elapsed: 0.0013
#
# frame 243, time 5.64
# label: 0.0
# Confidence: 0.5249
# Prediction: 1, elapsed: 0.0013
#
# frame 244, time 5.67
# label: 0.0
# Confidence: 0.5879
# Prediction: 1, elapsed: 0.0013
#
# frame 245, time 5.69
# label: 0.0
# Confidence: 0.4046
# Prediction: 0, elapsed: 0.0013
#
# frame 246, time 5.71
# label: 0.0
# Confidence: 0.3794
# Prediction: 0, elapsed: 0.0014
#
# frame 247, time 5.74
# label: 1.0
# Confidence: 0.4035
# Prediction: 0, elapsed: 0.0013
#
# frame 248, time 5.76
# label: 1.0
# Confidence: 0.4088
# Prediction: 0, elapsed: 0.0013
#
# frame 249, time 5.78
# label: 1.0
# Confidence: 0.4984
# Prediction: 0, elapsed: 0.0021
#
# frame 250, time 5.80
# label: 1.0
# Confidence: 0.4347
# Prediction: 0, elapsed: 0.0020
#
# frame 251, time 5.83
# label: 0.0
# Confidence: 0.4229
# Prediction: 0, elapsed: 0.0020
#
# frame 252, time 5.85
# label: 0.0
# Confidence: 0.4827
# Prediction: 0, elapsed: 0.0017
#
# frame 253, time 5.87
# label: 0.0
# Confidence: 0.6114
# Prediction: 1, elapsed: 0.0016
#
# frame 254, time 5.90
# label: 0.0
# Confidence: 0.5355
# Prediction: 1, elapsed: 0.0016
#
# frame 255, time 5.92
# label: 0.0
# Confidence: 0.3935
# Prediction: 0, elapsed: 0.0017
#
# frame 256, time 5.94
# label: 0.0
# Confidence: 0.5401
# Prediction: 1, elapsed: 0.0019
#
# frame 257, time 5.97
# label: 0.0
# Confidence: 0.5132
# Prediction: 1, elapsed: 0.0018
#
# frame 258, time 5.99
# label: 0.0
# Confidence: 0.6280
# Prediction: 1, elapsed: 0.0022
#
# frame 259, time 6.01
# label: 0.0
# Confidence: 0.3724
# Prediction: 0, elapsed: 0.0020
#
# frame 260, time 6.04
# label: 0.0
# Confidence: 0.5343
# Prediction: 1, elapsed: 0.0019
#
# frame 261, time 6.06
# label: 0.0
# Confidence: 0.4190
# Prediction: 0, elapsed: 0.0017
#
# frame 262, time 6.08
# label: 0.0
# Confidence: 0.3919
# Prediction: 0, elapsed: 0.0017
#
# frame 263, time 6.11
# label: 0.0
# Confidence: 0.5797
# Prediction: 1, elapsed: 0.0016
#
# frame 264, time 6.13
# label: 0.0
# Confidence: 0.5385
# Prediction: 1, elapsed: 0.0016
#
# frame 265, time 6.15
# label: 0.0
# Confidence: 0.4880
# Prediction: 0, elapsed: 0.0016
#
# frame 266, time 6.18
# label: 0.0
# Confidence: 0.5814
# Prediction: 1, elapsed: 0.0016
#
# frame 267, time 6.20
# label: 0.0
# Confidence: 0.3574
# Prediction: 0, elapsed: 0.0016
#
# frame 268, time 6.22
# label: 1.0
# Confidence: 0.3833
# Prediction: 0, elapsed: 0.0019
#
# frame 269, time 6.25
# label: 1.0
# Confidence: 0.3448
# Prediction: 0, elapsed: 0.0018
#
# frame 270, time 6.27
# label: 1.0
# Confidence: 0.4130
# Prediction: 0, elapsed: 0.0017
#
# frame 271, time 6.29
# label: 0.0
# Confidence: 0.4831
# Prediction: 0, elapsed: 0.0018
#
# frame 272, time 6.32
# label: 0.0
# Confidence: 0.5441
# Prediction: 1, elapsed: 0.0019
#
# frame 273, time 6.34
# label: 0.0
# Confidence: 0.4932
# Prediction: 0, elapsed: 0.0016
#
# frame 274, time 6.36
# label: 0.0
# Confidence: 0.5267
# Prediction: 1, elapsed: 0.0020
#
# frame 275, time 6.39
# label: 0.0
# Confidence: 0.4634
# Prediction: 0, elapsed: 0.0014
#
# frame 276, time 6.41
# label: 0.0
# Confidence: 0.2993
# Prediction: 0, elapsed: 0.0016
#
# frame 277, time 6.43
# label: 0.0
# Confidence: 0.4797
# Prediction: 0, elapsed: 0.0019
#
# frame 278, time 6.46
# label: 0.0
# Confidence: 0.3350
# Prediction: 0, elapsed: 0.0015
#
# frame 279, time 6.48
# label: 0.0
# Confidence: 0.5058
# Prediction: 1, elapsed: 0.0013
#
# frame 280, time 6.50
# label: 0.0
# Confidence: 0.5560
# Prediction: 1, elapsed: 0.0013
#
# frame 281, time 6.52
# label: 1.0
# Confidence: 0.4478
# Prediction: 0, elapsed: 0.0013
#
# frame 282, time 6.55
# label: 1.0
# Confidence: 0.4154
# Prediction: 0, elapsed: 0.0013
#
# frame 283, time 6.57
# label: 1.0
# Confidence: 0.5953
# Prediction: 1, elapsed: 0.0013
#
# frame 284, time 6.59
# label: 0.0
# Confidence: 0.5866
# Prediction: 1, elapsed: 0.0013
#
# frame 285, time 6.62
# label: 0.0
# Confidence: 0.4074
# Prediction: 0, elapsed: 0.0013
#
# frame 286, time 6.64
# label: 0.0
# Confidence: 0.6590
# Prediction: 1, elapsed: 0.0014
#
# frame 287, time 6.66
# label: 0.0
# Confidence: 0.3390
# Prediction: 0, elapsed: 0.0014
#
# frame 288, time 6.69
# label: 0.0
# Confidence: 0.4653
# Prediction: 0, elapsed: 0.0016
#
# frame 289, time 6.71
# label: 0.0
# Confidence: 0.4243
# Prediction: 0, elapsed: 0.0014
#
# frame 290, time 6.73
# label: 0.0
# Confidence: 0.6322
# Prediction: 1, elapsed: 0.0014
#
# frame 291, time 6.76
# label: 0.0
# Confidence: 0.4958
# Prediction: 0, elapsed: 0.0014
#
# frame 292, time 6.78
# label: 0.0
# Confidence: 0.4946
# Prediction: 0, elapsed: 0.0013
#
# frame 293, time 6.80
# label: 0.0
# Confidence: 0.5951
# Prediction: 1, elapsed: 0.0013
#
# frame 294, time 6.83
# label: 1.0
# Confidence: 0.3919
# Prediction: 0, elapsed: 0.0013
#
# frame 295, time 6.85
# label: 1.0
# Confidence: 0.2809
# Prediction: 0, elapsed: 0.0013
#
# frame 296, time 6.87
# label: 1.0
# Confidence: 0.3986
# Prediction: 0, elapsed: 0.0015
#
# frame 297, time 6.90
# label: 1.0
# Confidence: 0.4387
# Prediction: 0, elapsed: 0.0016
#
# frame 298, time 6.92
# label: 0.0
# Confidence: 0.4836
# Prediction: 0, elapsed: 0.0016
#
# frame 299, time 6.94
# label: 0.0
# Confidence: 0.5491
# Prediction: 1, elapsed: 0.0017
#
# frame 300, time 6.97
# label: 0.0
# Confidence: 0.4935
# Prediction: 0, elapsed: 0.0018
#
# frame 301, time 6.99
# label: 0.0
# Confidence: 0.5202
# Prediction: 1, elapsed: 0.0018
#
# frame 302, time 7.01
# label: 0.0
# Confidence: 0.3598
# Prediction: 0, elapsed: 0.0021
#
# frame 303, time 7.04
# label: 0.0
# Confidence: 0.6290
# Prediction: 1, elapsed: 0.0023
#
# frame 304, time 7.06
# label: 0.0
# Confidence: 0.3709
# Prediction: 0, elapsed: 0.0028
#
# frame 305, time 7.08
# label: 0.0
# Confidence: 0.4059
# Prediction: 0, elapsed: 0.0024
#
# frame 306, time 7.11
# label: 1.0
# Confidence: 0.4669
# Prediction: 0, elapsed: 0.0018
#
# frame 307, time 7.13
# label: 1.0
# Confidence: 0.4228
# Prediction: 0, elapsed: 0.0016
#
# frame 308, time 7.15
# label: 1.0
# Confidence: 0.4198
# Prediction: 0, elapsed: 0.0019
#
# frame 309, time 7.17
# label: 1.0
# Confidence: 0.6690
# Prediction: 1, elapsed: 0.0015
#
# frame 310, time 7.20
# label: 0.0
# Confidence: 0.5780
# Prediction: 1, elapsed: 0.0014
#
# frame 311, time 7.22
# label: 0.0
# Confidence: 0.4617
# Prediction: 0, elapsed: 0.0014
#
# frame 312, time 7.24
# label: 0.0
# Confidence: 0.4306
# Prediction: 0, elapsed: 0.0013
#
# frame 313, time 7.27
# label: 0.0
# Confidence: 0.5113
# Prediction: 1, elapsed: 0.0013
#
# frame 314, time 7.29
# label: 0.0
# Confidence: 0.5240
# Prediction: 1, elapsed: 0.0013
#
# frame 315, time 7.31
# label: 0.0
# Confidence: 0.4194
# Prediction: 0, elapsed: 0.0014
#
# frame 316, time 7.34
# label: 0.0
# Confidence: 0.4017
# Prediction: 0, elapsed: 0.0014
#
# frame 317, time 7.36
# label: 0.0
# Confidence: 0.5030
# Prediction: 1, elapsed: 0.0017
#
# frame 318, time 7.38
# label: 0.0
# Confidence: 0.5066
# Prediction: 1, elapsed: 0.0016
#
# frame 319, time 7.41
# label: 0.0
# Confidence: 0.4851
# Prediction: 0, elapsed: 0.0013
#
# frame 320, time 7.43
# label: 1.0
# Confidence: 0.4364
# Prediction: 0, elapsed: 0.0013
#
# frame 321, time 7.45
# label: 1.0
# Confidence: 0.3124
# Prediction: 0, elapsed: 0.0014
#
# frame 322, time 7.48
# label: 1.0
# Confidence: 0.4584
# Prediction: 0, elapsed: 0.0014
#
# frame 323, time 7.50
# label: 0.0
# Confidence: 0.5297
# Prediction: 1, elapsed: 0.0014
#
# frame 324, time 7.52
# label: 0.0
# Confidence: 0.4844
# Prediction: 0, elapsed: 0.0014
#
# frame 325, time 7.55
# label: 0.0
# Confidence: 0.5087
# Prediction: 1, elapsed: 0.0014
#
# frame 326, time 7.57
# label: 0.0
# Confidence: 0.4682
# Prediction: 0, elapsed: 0.0013
#
# frame 327, time 7.59
# label: 0.0
# Confidence: 0.3517
# Prediction: 0, elapsed: 0.0014
#
# frame 328, time 7.62
# label: 0.0
# Confidence: 0.3688
# Prediction: 0, elapsed: 0.0014
#
# frame 329, time 7.64
# label: 0.0
# Confidence: 0.6330
# Prediction: 1, elapsed: 0.0013
#
# frame 330, time 7.66
# label: 0.0
# Confidence: 0.4731
# Prediction: 0, elapsed: 0.0014
#
# frame 331, time 7.69
# label: 0.0
# Confidence: 0.4514
# Prediction: 0, elapsed: 0.0014
#
# frame 332, time 7.71
# label: 0.0
# Confidence: 0.3103
# Prediction: 0, elapsed: 0.0024
#
# frame 333, time 7.73
# label: 0.0
# Confidence: 0.5251
# Prediction: 1, elapsed: 0.0030
#
# frame 334, time 7.76
# label: 1.0
# Confidence: 0.3703
# Prediction: 0, elapsed: 0.0027
#
# frame 335, time 7.78
# label: 1.0
# Confidence: 0.3992
# Prediction: 0, elapsed: 0.0024
#
# frame 336, time 7.80
# label: 1.0
# Confidence: 0.3681
# Prediction: 0, elapsed: 0.0031
#
# frame 337, time 7.83
# label: 0.0
# Confidence: 0.5768
# Prediction: 1, elapsed: 0.0023
#
# frame 338, time 7.85
# label: 0.0
# Confidence: 0.5394
# Prediction: 1, elapsed: 0.0023
#
# frame 339, time 7.87
# label: 0.0
# Confidence: 0.4285
# Prediction: 0, elapsed: 0.0019
#
# frame 340, time 7.89
# label: 0.0
# Confidence: 0.3764
# Prediction: 0, elapsed: 0.0020

# %% [markdown]
# ## Export to ONNX

# %%
file = f"{projroot}/models/{model.name}/whistle.onnx"

torch.onnx.export(
    model,
    model.example_input[0],
    f = file,
    input_names=["input"],
    output_names=["output"],
)
